# %%
# It appears that the necessary library wasn't imported in the current session.
# Let's re-import the folium library and display the map again with the correct coordinates.

import folium

# Coordinates provided by the user
new_latitude = 47.57900943093803
new_longitude = 5.576702063852337

# Create a new map centered around the updated coordinates
updated_map = folium.Map(location=[new_latitude, new_longitude], zoom_start=15)

# Add a marker to the new location
folium.Marker([new_latitude, new_longitude], popup="Updated Location: Lieu Dit Le Roussot, 2 Chemin du Moulin").add_to(updated_map)

# Display the updated map
updated_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
