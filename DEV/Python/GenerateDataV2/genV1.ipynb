# %%
# Parameters
NUM_AGENTS = 5
NUM_MEETINGS = 15
AGENT_SKILLS = ['fire_cert', 'bodyguard_cert', 'first_aid', 'security_clearance']
NIGHT_SHIFTS_PER_AGENT_PER_WEEK = 1
AGENT_HOURS_PER_WEEK = 40
MEETING_DURATION_OPTIONS = [1, 2, 3]  # In hours

# %%
import random

def generate_agents(num_agents):
    agents = []
    for i in range(num_agents):
        agent = {
            'agent_id': f'Agent_{i+1}',
            'skills': random.sample(AGENT_SKILLS, random.randint(1, len(AGENT_SKILLS))),
            'home_location': (
                random.uniform(46.160963, 46.235041),  # Latitude range
                random.uniform(6.059573, 6.183324)     # Longitude range
            ),
            'night_shifts_per_week': NIGHT_SHIFTS_PER_AGENT_PER_WEEK,
            'weekly_hours': AGENT_HOURS_PER_WEEK
        }
        agents.append(agent)
    return agents

agents = generate_agents(NUM_AGENTS)

# %%
def generate_meetings(num_meetings):
    meetings = []
    for i in range(num_meetings):
        meeting_duration = random.choice(MEETING_DURATION_OPTIONS)
        meeting = {
            'meeting_id': f'Meeting_{i+1}',
            'required_skill': random.choice(AGENT_SKILLS),
            'location': (
                random.uniform(46.160963, 46.235041),
                random.uniform(6.059573, 6.183324)
            ),
            'time_window': (
                random.randint(8, 16),  # Start hour
                random.randint(9, 18)   # End hour
            ),
            'duration': meeting_duration
        }
        # Ensure the time window makes sense
        if meeting['time_window'][1] - meeting['time_window'][0] < meeting_duration:
            meeting['time_window'] = (
                meeting['time_window'][0],
                meeting['time_window'][0] + meeting_duration
            )
        meetings.append(meeting)
    return meetings

meetings = generate_meetings(NUM_MEETINGS)

# %%
def generate_meetings(num_meetings):
    meetings = []
    for i in range(num_meetings):
        meeting_duration = random.choice(MEETING_DURATION_OPTIONS)
        meeting = {
            'meeting_id': f'Meeting_{i+1}',
            'required_skill': random.choice(AGENT_SKILLS),
            'location': (
                random.uniform(46.160963, 46.235041),
                random.uniform(6.059573, 6.183324)
            ),
            'time_window': (
                random.randint(8, 16),  # Start hour
                random.randint(9, 18)   # End hour
            ),
            'duration': meeting_duration
        }
        # Ensure the time window makes sense
        if meeting['time_window'][1] - meeting['time_window'][0] < meeting_duration:
            meeting['time_window'] = (
                meeting['time_window'][0],
                meeting['time_window'][0] + meeting_duration
            )
        meetings.append(meeting)
    return meetings

meetings = generate_meetings(NUM_MEETINGS)

# %%
import folium

# Create a map centered around Geneva
map_geneva = folium.Map(location=[46.2044, 6.1432], zoom_start=13)

# Add agent home locations
for agent in agents:
    folium.Marker(
        location=agent['home_location'],
        popup=f"{agent['agent_id']} Skills: {', '.join(agent['skills'])}",
        icon=folium.Icon(color='blue', icon='user')
    ).add_to(map_geneva)

# Add meeting locations
for meeting in meetings:
    folium.Marker(
        location=meeting['location'],
        popup=f"{meeting['meeting_id']} Required Skill: {meeting['required_skill']}",
        icon=folium.Icon(color='red', icon='briefcase')
    ).add_to(map_geneva)

map_geneva
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abe6edd1caf620b63afeb9c85000d981 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abe6edd1caf620b63afeb9c85000d981&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abe6edd1caf620b63afeb9c85000d981 = L.map(
#                 &quot;map_abe6edd1caf620b63afeb9c85000d981&quot;,
#                 {
#                     center: [46.2044, 6.1432],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa9819c01a890c4ef33bec9ef03b3c66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fa9819c01a890c4ef33bec9ef03b3c66.addTo(map_abe6edd1caf620b63afeb9c85000d981);
#
#
#             var marker_2ce3f90d493893072067aa8636cf2fbd = L.marker(
#                 [46.22421206591274, 6.177919584214914],
#                 {}
#             ).addTo(map_abe6edd1caf620b63afeb9c85000d981);
#
#
#             var icon_1063cbcaafc54ec21c0401978e77208b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ce3f90d493893072067aa8636cf2fbd.setIcon(icon_1063cbcaafc54ec21c0401978e77208b);
#
#
#         var popup_87db29777f4cc462ee8fb53523a59f62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cbfe5922e149466636761f15c254bfcf = $(`&lt;div id=&quot;html_cbfe5922e149466636761f15c254bfcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agent_1 Skills: security_clearance, fire_cert, first_aid, bodyguard_cert&lt;/div&gt;`)[0];
#                 popup_87db29777f4cc462ee8fb53523a59f62.setContent(html_cbfe5922e149466636761f15c254bfcf);
#
#
#
#         marker_2ce3f90d493893072067aa8636cf2fbd.bindPopup(popup_87db29777f4cc462ee8fb53523a59f62)
#         ;
#
#
#
#
#             var marker_f9e3b28958e4660837be385d7e36ddc6 = L.marker(
#                 [46.17899009571704, 6.087530275347303],
#                 {}
#             ).addTo(map_abe6edd1caf620b63afeb9c85000d981);
#
#
#             var icon_1db07981f941dcf8f80b40943a3b6a1e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f9e3b28958e4660837be385d7e36ddc6.setIcon(icon_1db07981f941dcf8f80b40943a3b6a1e);
#
#
#         var popup_efeb9518e166c2185036a0584f8dadf5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c751ccf2ec10b7754c801143bd87a19b = $(`&lt;div id=&quot;html_c751ccf2ec10b7754c801143bd87a19b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agent_2 Skills: security_clearance&lt;/div&gt;`)[0];
#                 popup_efeb9518e166c2185036a0584f8dadf5.setContent(html_c751ccf2ec10b7754c801143bd87a19b);
#
#
#
#         marker_f9e3b28958e4660837be385d7e36ddc6.bindPopup(popup_efeb9518e166c2185036a0584f8dadf5)
#         ;
#
#
#
#
#             var marker_7c6396e6abafa94dc716fe4ffbaf6ea0 = L.marker(
#                 [46.163083286751416, 6.083818447718972],
#                 {}
#             ).addTo(map_abe6edd1caf620b63afeb9c85000d981);
#
#
#             var icon_ebdc96849e6001a8030f2beb8cb0bd92 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c6396e6abafa94dc716fe4ffbaf6ea0.setIcon(icon_ebdc96849e6001a8030f2beb8cb0bd92);
#
#
#         var popup_af5104fcbb6a2eac1f99717f1a0a60d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cbcd980b5e21e83f929eca0aed90a46 = $(`&lt;div id=&quot;html_5cbcd980b5e21e83f929eca0aed90a46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agent_3 Skills: fire_cert&lt;/div&gt;`)[0];
#                 popup_af5104fcbb6a2eac1f99717f1a0a60d8.setContent(html_5cbcd980b5e21e83f929eca0aed90a46);
#
#
#
#         marker_7c6396e6abafa94dc716fe4ffbaf6ea0.bindPopup(popup_af5104fcbb6a2eac1f99717f1a0a60d8)
#         ;
#
#
#
#
#             var marker_ca3c864c214ad5424b429af58f851fff = L.marker(
#                 [46.20495819102423, 6.110676489950001],
#                 {}
#             ).addTo(map_abe6edd1caf620b63afeb9c85000d981);
#
#
#             var icon_3985002ff02e149c3a028605b3cb7073 = L.AwesomeMarkers.icon(
#                 {&

# %%
import json

# Prepare data for Timefold
timefold_data = {
    'vehicles': [
        {
            'name': agent['agent_id'],
            'homeLocation': agent['home_location'],
            'capacity': agent['weekly_hours'],
            'skills': agent['skills']
        }
        for agent in agents
    ],
    'visits': [
        {
            'name': meeting['meeting_id'],
            'location': meeting['location'],
            'required_skill': meeting['required_skill'],
            'time_window': meeting['time_window'],
            'duration': meeting['duration']
        }
        for meeting in meetings
    ]
}

# Save to JSON file with indentation
with open('timefold-data.json', 'w') as f:
    json.dump(timefold_data, f, indent=4)  # Added indent parameter
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
